# %%
from pdp.phonon_projections import PhonopySumoProjections
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/GaAs/FORCE_SETS',
                                 unitcell='../example/GaAs/POSCAR',
                                 dim=[4,4,4])
# %time bs = phonons.get_sumo_phonons()
# %time phonons.create_plot_scatter(bs=bs,element='Ga',cmap='Greens',ax=ax1)
# %time phonons.create_plot_scatter(bs=bs,element='As',cmap='Purples',ax=ax2)
ax1.set_title('Ga')
ax2.set_title('As')
plt.savefig('../example/GaAs/gaas.png',transparent=True)
plt.show()
# Out:
# CPU times: user 2.14 s, sys: 58.5 ms, total: 2.2 s
# Wall time: 1.19 s
# CPU times: user 92 ms, sys: 940 µs, total: 93 ms
# Wall time: 88.7 ms
# CPU times: user 269 ms, sys: 6.92 ms, total: 276 ms
# Wall time: 92.6 ms
# /var/folders/3t/k_85c0hx7798gpb5pqvjw6kr0000gn/T/ipykernel_48859/3274211110.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/ZnO/FORCE_CONSTANTS',
                                 unitcell='../example/ZnO/POSCAR',
                                 dim=[1,1,1])
phonons.create_plot_scatter(element='Zn',cmap='Blues',ax=ax1)
phonons.create_plot_scatter(element='O',cmap='Reds',ax=ax2)
ax1.set_title('Zn')
ax2.set_title('O')
plt.savefig('../example/ZnO/zno.png',transparent=True)
plt.show()
# Out:
# <ipython-input-3-93ef4eec09aa>:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
