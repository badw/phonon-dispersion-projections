# %%
from pdp.phonon_projections import PhonopySumoProjections
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/GaAs/FORCE_SETS',
                                 unitcell='../example/GaAs/POSCAR',
                                 dim=[4,4,4])
bs = phonons.get_sumo_phonons()
phonons.create_plot_scatter(bs=bs,element='Ga',cmap='Greens',ax=ax1)
phonons.create_plot_scatter(bs=bs,element='As',cmap='Purples',ax=ax2)
ax1.set_title('Ga')
ax2.set_title('As')
plt.savefig('../example/GaAs/gaas.png',transparent=True)
plt.show()
# Out:
# /var/folders/3t/k_85c0hx7798gpb5pqvjw6kr0000gn/T/ipykernel_94940/2478973983.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/ZnO/FORCE_CONSTANTS',
                                 unitcell='../example/ZnO/POSCAR',
                                 dim=[1,1,1])
bs = phonons.get_sumo_phonons()
phonons.create_plot_scatter(bs=bs,element=[0,1],cmap='Blues',ax=ax1)
phonons.create_plot_scatter(bs=bs,element=[2,3],cmap='Reds',ax=ax2)
ax1.set_title('Zn')
ax2.set_title('O')
plt.savefig('../example/ZnO/zno.png',transparent=True)
plt.show()
# Out:
# /var/folders/3t/k_85c0hx7798gpb5pqvjw6kr0000gn/T/ipykernel_94940/3528334043.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
