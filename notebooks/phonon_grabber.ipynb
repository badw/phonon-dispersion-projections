# %%
from pdp.phonon_projections import PhonopySumoProjections
import matplotlib.pyplot as plt

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCE_SETS='../example/GaAs/FORCE_SETS',
                                 unitcell='../example/GaAs/POSCAR',
                                 dim=[4,4,4])
phonons.create_plot_scatter(element='Ga',cmap='Blues',ax=ax1)
phonons.create_plot_scatter(element='As',cmap='Reds',ax=ax2)
ax1.set_title('Ga')
ax2.set_title('As')
plt.savefig('../example/GaAs/gaas.png')
plt.show()
# Out:
# <ipython-input-5-2398e11ab1d0>:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
