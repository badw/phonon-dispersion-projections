# %%
from pdp.phonon_projections import PhonopySumoProjections
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/GaAs/FORCE_SETS',
                                 unitcell='../example/GaAs/POSCAR',
                                 dim=[4,4,4])
phonons.create_plot_scatter(element='Ga',cmap='Greens',ax=ax1)
phonons.create_plot_scatter(element='As',cmap='Purples',ax=ax2)
ax1.set_title('Ga')
ax2.set_title('As')
plt.savefig('../example/GaAs/gaas.png',transparent=True)
plt.show()
# Out:
# <ipython-input-2-48d12a8c6a43>:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/ZnO/FORCE_CONSTANTS',
                                 unitcell='../example/ZnO/POSCAR',
                                 dim=[1,1,1])
phonons.create_plot_scatter(element='Zn',cmap='Blues',ax=ax1)
phonons.create_plot_scatter(element='O',cmap='Reds',ax=ax2)
ax1.set_title('Zn')
ax2.set_title('O')
plt.savefig('../example/ZnO/zno.png',transparent=True)
plt.show()
# Out:
# <ipython-input-3-93ef4eec09aa>:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
fig,(ax1,ax2)= plt.subplots(1,2,figsize=(12,6),dpi=300)
phonons = PhonopySumoProjections(FORCES='../example/zno_super/FORCE_CONSTANTS',
                                 unitcell='../example/ZnO/POSCAR',
                                 dim=[2,2,2])
phonons.create_plot_scatter(element='Zn',cmap='Blues',ax=ax1)
phonons.create_plot_scatter(element='O',cmap='Reds',ax=ax2)
ax1.set_title('Zn')
ax2.set_title('O')
plt.savefig('../example/zno_super/zno_super.png',transparent=True)
plt.show()
# Out:
# <ipython-input-5-344b19753d53>:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
